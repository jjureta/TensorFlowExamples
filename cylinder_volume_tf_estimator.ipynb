# %% [markdown]
# ## Challenge Exercise
#
# Create a neural network that is capable of finding the volume of a cylinder given the radius of its base (r) and its height (h). Assume that the radius and height of the cylinder are both in the range 0.5 to 2.0. Simulate the necessary training dataset.

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import shutil
import math
import logging

print(tf.__version__)

# %%
DF_COLUMNS = ['r', 'h','V']
FEATURES = DF_COLUMNS[0:len(DF_COLUMNS) - 1]
LABEL = DF_COLUMNS[2]

# %%
# Create a dataset containing random radius (r) and height (h) columns and V which is pi*r*r*h
# min minumum value of r and h
# max maximum value of r and h
# size size of the data set
def create_df(min, max, size):
    # create df with columns r and h containing random valuse
    df = pd.DataFrame( (max - min) * np.random.random(size=(size, 2)) + min, columns=list('rh'))
    df["V"] = math.pi * df.r ** 2 * df.h
    return df

# %%
def print_rmse(model, df):
  metrics = model.evaluate(input_fn = make_eval_input_fn(df))
  print('RMSE on dataset = {}'.format(np.sqrt(metrics['average_loss'])))

# %%
def make_train_dataset(df, num_epochs):
    ds = tf.data.Dataset.from_tensor_slices((df[FEATURES].values, df[LABEL].values))
    ds = ds.shuffle(buffer_size=len(df)).repeat(num_epochs).batch(128)
    return ds

# %%
def make_eval_dataset(df):
    ds = tf.data.Dataset.from_tensor_slices((df[FEATURES].values, df[LABEL].values))
    ds = ds.batch(128)
    return ds

# %%
def make_prediction_dataset(df):
    ds = tf.data.Dataset.from_tensor_slices(df[FEATURES].values)
    ds = ds.batch(128)
    return ds

# %%
def make_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(2,)),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(8, activation='relu'),
        tf.keras.layers.Dense(2, activation='relu'),
        tf.keras.layers.Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# %%
min_val = 0.5
max_val = 2

df_train = create_df(min_val, max_val, 10000)
df_valid = create_df(min_val, max_val, 200)
df_test = create_df(min_val, max_val, 200)

# %%
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

model = make_model()
train_ds = make_train_dataset(df_train, num_epochs=10)
val_ds = make_eval_dataset(df_valid)
history = model.fit(train_ds, epochs=10, validation_data=val_ds, verbose=1)
eval_result = model.evaluate(val_ds)
print(f"RMSE on validation set = {eval_result[1]}")

# %%
pred_ds = make_prediction_dataset(df_test)
predictions = model.predict(pred_ds)
for item in predictions:
    print(item)

# %%
print(type(predictions))
predictions_df = pd.DataFrame({'Prediction': predictions.flatten()})
predictions_df.head()
